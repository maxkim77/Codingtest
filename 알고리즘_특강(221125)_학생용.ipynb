# %% [markdown]
# <a href="https://colab.research.google.com/github/maxkim77/Codingtest/blob/main/%EC%95%8C%EA%B3%A0%EB%A6%AC%EC%A6%98_%ED%8A%B9%EA%B0%95(221125)_%ED%95%99%EC%83%9D%EC%9A%A9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. 자료구조와 알고리즘, 코딩테스트

# %% [markdown]
# * 추천 서적
#     * 학문적 접근 : The Art of Computer Programming(도널드 커누스)
#     * 코딩테스트 접근 : 파이썬 알고리즘 인터뷰(박상길)
#     * 기타 : 파이썬 자료구조와 알고리즘(중학교 학생 가르칠 때 사용), 그림으로 배우는 알고리즘(코드 없고 그림만 있습니다), 알고리즘 산책(역사적인 알고리즘을 쭉 훑어봅니다. 수학적인 내용이 많고 코드는 C++로 되어 있으나 보는데 큰 무리는 없습니다.)

# %% [markdown]
# ## 1.1 코테 전 준비사항
#
# 1. 플렛폼에 익숙해지자! (프로그래머스, 구름EDU 등)
#     * 사용 가능 라이브러리 미리 확인 등
#     * 대부분 numpy나 pandas 같은 라이브러리 사용 금지이지만 간혹가다 제한이 없는 곳도 있습니다. numpy는 python보다 대부분의 경우 속도가 빠릅니다. 크기에 따라 다르지만 100000개 이상의 배열의 연산의 경우 50배 이상의 성능을 보입니다.
# 2. 언어 선택(속도 : C++, 풀이 : Python)
# 3. 코드 스니펫(트리, 검색, 최단경로(예를 들어 다익스트라), 직접 제작한 함수 등), Cheatsheet, A4 용지 준비
#     * 코드 스니펫을 만들어둔 레파지토리 fork - [제주코딩베이스캠프](https://github.com/paullabkorea/programmersLv0)
#     * 시험 전 스니펫을 만들지 말고 하루 한 문제씩(저도 매일 한 문제씩 풉니다.)
# 4. 유용한 라이브러리 정리! (collections, itertools(순열, 조합), functools, itertools, re, bisect, math 등) - [제주코딩베이스캠프](https://www.youtube.com/channel/UC4GnvNKtuJ4cqWsYjxNxAEQ) 유튜브 채널 확인
# 5. 기억해두자! 예외처리!
# 6. 속도개선
#     1. class로 구현
#     2. 메서드 대신 슬라이싱 구현(슬라이싱은 C로 구현되어 있어 메서드보다 통상 8배정도 빠릅니다.)하세요. 다만 공간복잡도가 상승할 수 있습니다. (리스트.reverse(), reversed(리스트), 리스트[::-1])
#     3. for문 대신 list comprehension을 사용하세요. 더 빠릅니다.
#     4. 재귀는 느립니다. 최후의 수단으로 사용하세요.

# %% [markdown]
# ## 1.2 문제 유형과 출제 방식
# * 5 ~ 6시간, 6 ~ 7문제
# * 30분씩 4문제, 2시간씩 2문제
# * 문제 유형 분석 관련 글
#     * [문제 유형 분석](https://www.hanbit.co.kr/media/channel/view.html?cms_code=CMS4385594264)
#     * [언어 유불리 여부](https://www.hanbit.co.kr/media/channel/view.html?cms_code=CMS9145550324&cate_cd=)
#     * [코딩 테스트에 가장 많이 출제 되는 알고리즘](https://www.hanbit.co.kr/media/channel/view.html?cms_code=CMS7793635735&cate_cd=)
#         * 요구사항 구현 알고리즘(33%)
#         * 그리디 알고리즘(20%)
#         * 너비우선탐색, 깊이우선탐색(20%)
#         * 정렬(8%)
#         * 다이나믹 프로그래밍, 최단경로, 이진 탐색 등
# * 전체 문제 유형
#     * 알고리즘
#         * 정렬
#         * 이진 검색
#         * 비트 연산
#         * 슬라이딩 윈도우, 페이지 교체
#         * 분할 정복
#             * 그리디 알고리즘
#             * 다이나믹 프로그래밍
#     * 자료구조
#         * 선형
#             * 스택과 큐, 데크
#             * 연결리스트, 해시 테이블
#         * 비선형
#             * 그래프(최단경로) - 다익스트라가 나오면 매우 어려운 문제
#             * 트리
#                 * 힙
#                 * 트라이

# %% [markdown]
# ## 1.3 워밍업 문제

# %% [markdown]
# ### 1.3.1 1번 워밍업 문제(google)
#
# 1부터 10,000까지 8이라는 숫자가 총 몇번 나오는가?
#
# 8이 포함되어 있는 숫자의 갯수를 카운팅 하는 것이 아니라 8이라는 숫자를 모두 카운팅 해야 한다.
# (※ 예를들어 8808은 3, 8888은 4로 카운팅 해야 함)
#
# 문제 링크 : https://codingdojang.com/scode/393

# %%
list(range(20))
str(list(range(20)))
str(list(range(20))).count('1')
# Out:
# 12

# %%
# %%timeit
count = 0

for i in range(1, 101):
    if '8' in str(i):
        count += str(i).count('8')

count
# Out:
# 21.1 µs ± 609 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %%time it
str(list(range(1, 101))).count('1')
# Out:
# UsageError: Can't use statement directly after '%%time'!

# %%
str([i for i in range(1,101)]).count('8')
# Out:
# 20

# %% [markdown]
# ### 1.3.2 2번 워밍업 문제(daum)
#
# 1차원의 점들이 주어졌을 때, 그 중 가장 거리가 짧은 것의 쌍을 출력하는 함수를 작성하시오. (단 점들의 배열은 모두 정렬되어있다고 가정한다.)
#
# 예를들어 S = [1, 3, 4, 8, 13, 17, 20] 이 주어졌다면, 결과값은 (3, 4)가 될 것이다.
#
# 문제링크 : https://codingdojang.com/scode/408

# %%
s = [1,3,4,8,13,17,20]
ss = s[1:]
ss
# Out:
# [3, 4, 8, 13, 17, 20]

# %%
list(zip(s, ss))
# Out:
# [(1, 3), (3, 4), (4, 8), (8, 13), (13, 17), (17, 20)]

# %%
sorted(zip(s, ss), key=lambda x:x[1]-x[0])
sorted(zip(s, ss), key=lambda x:x[1]-x[0])[0]
# Out:
# (3, 4)

# %%
#max, min, sorted를 사용하지 않고
#최솟값 최댓값은 직접 구현하실 수 있어야합니다.
#최솟값
d = [10, 2, 3, 7, 15, 3, 6]
temp = float('inf')
for i in d:
    if temp > i:
        temp = i
print(temp)
# Out:
# 2

# %%
#최댓값
#최댓값은 최솟값을 가지고 비교
d = [10, 2, 3, 7, 15, 3, 6]
temp = -float('inf')
for i in d:
    if temp < i:
        temp = i
print(temp)
# Out:
# 15

# %%
#최솟값
#최댓값을 기본으로
#관습적으로 쓰임
l = [1,3,4,8,13, 17,20]
temp = float('inf')
for i in range(len(l) - 1):
    if temp > (l[i+1] - l[i]):
        temp = l[i+1] - l[i]
print(temp)
# Out:
# 1

# %%
# 혼자 코딩하실 때 사용하세요.ㅎㅎ
l = [1, 3, 4, 8, 13, 17, 20]
temp = float('inf')
index = 0
for i in range(1, len(l)):
    if temp > (l[i] - l[i-1]): # out of range 이 애러가 많이 납니다.
        temp = l[i] - l[i-1]
        index = i
print(temp)
print(l[index-1], l[index])
# Out:
# 1
# 3 4

# %% [markdown]
# ## 1.4 기본 자료구조 및 알고리즘
# 1. 스택과 큐
# 2. 연결리스트
# 3. 트리와 그래프
#     * 3.1 트리 구현
#     * 3.2 트리의 순회
# 4. 정렬 알고리즘
#     * 4.1 선택정렬
#     * 4.2 삽입정렬
#     * 4.3 병합정렬
#     * 4.4 퀵정렬
# 5. 페이지 교체 알고리즘
# 6. 슬라이딩 윈도우와 투 포인터 알고리즘

# %% [markdown]
# ### 1.4.1 스택과 큐
# * 스택과 큐는 프로그래밍 언어가 생겨날 때부터 있었던 매우 고전적인 개념
# * 스택은 LIFO(Last-In-First-Out, 후입선출)
# * 큐는 FIFO(First-In_First-Out, 선입선출)
# * 특히 알고리즘 문제에서 너비우선 탐색과 깊이 우선탐색에 응용됨
# * 리스트가 스택과 큐의 모든 연산이 구현되어 있음
# * ADT(Abstract Data Type)
#     * S.top(): 스택의 가장 윗 데이터를 반환한다. 만약 스택이 비었다면 이 연산은 정의불가 상태이다.
#     * S.pop(): 스택의 가장 윗 데이터를 삭제한다. 스택이 비었다면 연산 정의불가 상태.
#     * S.push(): 스택의 가장 윗 데이터로 top이 가리키는 자리 위에(top = top + 1) 메모리를 생성, 데이터 x를 넣는다.
#     * S.empty(): 스택이 비었다면 1을 반환하고,그렇지 않다면 0을 반환한다.

# %%
#이런문제는 정보처리기사에만 나옵니다.
#코테랑은 관련없고, 개념을 제대로 이해하고 있는지 보는 것입니다.
#다음중 스택이 아닌 것은?
# 1,2,3,4,5 순서로 데이터가 들어갑니다.
# 1, [5,4,3,2,1](스택 0)
# 2. [3,2,1,5,4](스택 0)
# 3. [1,2,3,4,5](스택 0)
# 4. [2,1,4,3,5](스택 0)

# %%
s = [1,2,3,4,5]
s.append(6)
s.pop()
# Out:
# 6

# %% [markdown]
# 큐
#
#
# 먼저 들어간 요소가 먼저 나옵니다.
#
#
# 다음 중 큐가 아닌것은?
#
#
# [1,2,3,4,5]가 순서대로 데이터에 삽입된다. 다음중 큐인 것은? 1번
#
#
# 1. [1,2,3,4,5]
#
#
# 2. 어떤값이든 아닙니다.

# %%
q = [1,2,3,4,5]
q.append(6)
q.pop(0)
# Out:
# 1

# %%
q = [1,2,3,4,5]
q.insert(0,6)
q.pop()
# Out:
# 5

# %% [markdown]
# ### 1.4.2 연결리스트
# * 연결리스트, 메모리 효율을 위해 사용되는 경우가 많음
# * 다른 자료 구조를 만들기위해 많이 사용
# * 개념 : https://en.wikipedia.org/wiki/Linked_list
# * 알고리즘 시각화 : https://visualgo.net/ko

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#요구사항 분석
#filed는 2가지를 가지고 있습니다.
#1. data
#2. next
#어떤 자료 구조를 사용할까요? dict를 사용한 이유는 필드 이름으로 값을 호출 할 수 있기 때문에 dict를 선택한 것입니다.
#dict를 사용한 이유는 필드 이름으로 값을 호출 할 수 있기 때문에 dict를 선택한 것입니다.
#l = [[data, next], [data, next], [data,next], [data,next]]
#l = {'data': data, 'next':{'data':data, 'next':{'data':data, 'next':next}}}
#d = [{'data': data, 'next':{'data':data, 'next':{'data':data, 'next': next}}}]
#앞에서 어떤 것으로 구현했던 우리가 최종적으로 구현해야 되는 모습은
#class에 instance로 구현해야합니다.
#왜 해야하나요?
#빠르고, 다른 자료구조를 구현할 수 있습니다.
# 코딩테스트 효율성 테스트를 통과하기 위해서(7문제 나오면 효율성테스트는)
#이렇게 구현하면 느립니다! 노드가 딕셔너리인데, 리스트나 딕셔너리는 무겁습니다.
#12, 99, 37
linked_list = {
    'head':{
        'data': 12,
        'next': {
            'data': 99,
            'next':{
                'data': 37,
                'next': None
            }
        }
    }
}
linked_list['head']
linked_list['head']['data']
linked_list['head']['next']
linked_list['head']['next']['next']['data']
# Out:
# 37

# %%
linked_list = {
    'head':{
        'data': 90,
        'next': {
            'data': 2,
            'next':{
                'data': 77,
                'next': {
                    'data': 35,
                    'next': {
                        'data': 21,
                        'next':{None}
                    }
                }
            }
        }
    }
}
linked_list['head']
linked_list['head']['data']
linked_list['head']['next']
linked_list['head']['next']['next']['data']
linked_list['head']['next']['next']
linked_list['head']['next']['next']['next']['data']
# Out:
# 35

# %% [markdown]
# Quiz)
# * head -> [90, next] -> [2, next] -> [77, next] -> [35, next] -> [21, next] -> None
# * 35를 출력해주세요.

# %%
# head -> [90, next] -> [2, next] -> [77, next] -> [35, next] -> [21, next] -> None
linked_list = {}
node1 = {'data': 90, 'next': None} # 이제 이것을 인스턴스로 만들겁니다!
node2 = {'data': 2, 'next': None}
node3 = {'data': 77, 'next': None}
node4 = {'data': 35, 'next': None}
node5 = {'data': 21, 'next': None}

node1['next'] = node2
node2['next'] = node3
node3['next'] = node4
node4['next'] = node5

linked_list['head'] = node1

linked_list['head']['next']['next']['next']['data']
# Out:
# 35

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

head = Node('head')
node1 = Node(90)
node2 = Node(2)
node3 = Node(77)
node4 = Node(35)
node5 = Node(21)

node1.next = node2
node2.next = node3
node3.next = node4
node4.next = node5

head.next = node1
head.next.next.next.next.data
# Out:
# 35

# %%
# head -> [90, next] -> [2, next] -> [77, next] -> [35, next] -> [21, next] -> None
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

head = Node('head')

node1 = Node(90)
node2 = Node(2)
node3 = Node(77)
node4 = Node(35)
node5 = Node(21)

node1.next = node2
node2.next = node3
node3.next = node4
node4.next = node5

head.next = node1

head.next.next.next.next.data
# Out:
# 35

# %%
current = head.next

current = current.next #current = head.next.next
current = current.next #current = head.next.next.next
current = current.next #current = head.next.next.next.next

print(current.data)
# Out:
# 35

# %%
current = head.next
for i in range(4): #원하는 만큼 다음 값을 호출 합니다.
    current = current.next
print(current.data)
# Out:
# 21

# %%
# 이게 너무 귀찮아요!
# node1.next = node2
# node2.next = node3
# node3.next = node4
# node4.next = node5

# linked_list.append(3) # 이렇게 하고 싶습니다!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList: # list, tuple, dict처럼 하나에 자료형을 만드는 것입니다!
    def __init__(self):
        init = Node('init')
        self.head = init
        self.tail = init
        self.count = 0

    def __len__(self):
        return self.count

    def append(self, data):
        new_node = Node(data)
        self.count += 1
        self.tail.next = new_node # 처음에는 Node('init').next
        self.tail = new_node

l = LinkedList()
l.append(10)
l.append(20)
l.append(30)

# l.head.next.data
# l.head.next.next.data
# l.head.next.next.next.data

l.head.data
l.tail.data
# print(l.tail.next)
# Out:
# 30

# %%
# head -> [90, next] -> [2, next] -> [77, next] -> [35, next] -> [21, next] -> None
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

init = Node('head')
head = init
tail = init

node1 = Node(90) # tail.next = Node(90)
tail = node1

node2 = Node(2) # tail.next = Node(2), 여기서 tail은 누구인가요? node1 즉 Node(90)입니다.
tail = node2

node3 = Node(77)
tail = node3

node4 = Node(35)
tail = node4

node5 = Node(21)
tail = node5

node1.next = node2
node2.next = node3
node3.next = node4
node4.next = node5

head.next = node1

head.next.next.next.next.data
# Out:
# 35

# %% [markdown]
# node 설명
# 1. node가 1개도 없을 때
# ```
# self.head
#     ↓
# data: 'init'
# next: None
#     ↑
# self.tail
# ```
# 2. node가 1번째로 들어왔을 때(10 데이터 삽입)
# ```
# self.head
#     ↓
# data: 'init'       data: 10
# next: --------->   next: None
#                        ↑
#                     self.tail
# ```
# ```python
# # 이코드가 수행
# self.tail.next = new_node # 처음에는 Node('init').next
# self.tail = new_node
# ```
#
# 3. node가 2번째로 들어왔을 때(10 데이터 삽입 이후 20 데이터 삽입)
# ```
# self.head
#     ↓
# data: 'init'       data: 10           data: 20
# next: --------->   next:  --------->  next: None
#                                           ↑
#                                        self.tail
# ```
# ```python
# # 이코드가 수행
# self.tail.next = new_node # 처음에는 Node('init').next
# self.tail = new_node
# ```

# %%
#메서드 추가해볼게요!
# __str__
# __repr__

# %%
# 메서드 추가해볼게요!
# pop, find

class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList: # list, tuple, dict처럼 하나에 자료형을 만드는 것입니다!
    def __init__(self):
        init = Node('init')
        self.head = init
        self.tail = init
        self.count = 0

    def __len__(self):
        return self.count

    def __getitem__(self, index):
        current = self.head.next
        for _ in range(index):
            current = current.next
        return current.data

    def __str__(self):
        current = self.head.next
        result = ''
        for _ in range(self.count):
            result += f'{str(current.data)}, '
            current = current.next
        return f'<{result[:-2]}>'

    def __repr__(self):
        current = self.head.next
        result = ''
        for _ in range(self.count):
            result += f'{str(current.data)}, '
            current = current.next
        return f'<{result[:-2]}>'

    def append(self, data):
        new_node = Node(data)
        self.count += 1
        self.tail.next = new_node # 처음에는 Node('init').next
        self.tail = new_node

    def pop(self):
        if self.count == 0:
            raise IndexError('pop from empty list')
        last_node_data = self.tail.data
        current = self.head.next
        for _ in range(self.count):
            if current.next is self.tail:
                self.tail = current
                break
            current = current.next
        self.count -= 1
        return last_node_data

    def find(self):
        if self.count == 0:
            return -1
        current = self.head.next
        for _ in range(self.count):
            current = current.next


l = LinkedList()
l.append(10)
l.append(20)
l.append(30)
l.append(40)

len(l)
print(l) # 출력: <10, 20, 30, 40>
l[2]

print(l.pop()) # 출력: 40
print(l) # 출력: <10, 20, 30>

print(l.pop()) # 출력: 30
print(l) # 출력: <10, 20>

print(l.pop()) # 출력: 20
print(l) # 출력: <10>
len(l)

# error 확인
print(l.pop())
print(l)

print(l.pop())
print(l)
# Out:
# <10, 20, 30, 40>
# 40
# <10, 20, 30>
# 30
# <10, 20>
# 20
# <10>
# 10
# <>
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-69-119ba79ef78e> in <cell line: 92>()
#      90 print(l)
#      91
# ---> 92 print(l.pop())
#      93 print(l)
#
# <ipython-input-69-119ba79ef78e> in pop(self)
#      47     def pop(self):
#      48         if self.count == 0:
# ---> 49             raise IndexError('pop from empty list')
#      50         last_node_data = self.tail.data
#      51         current = self.head.next
#
# IndexError: pop from empty list

# %%
l = []
l.pop()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-66-3290a6f44f1f> in <cell line: 2>()
#       1 l = []
# ----> 2 l.pop()
#
# IndexError: pop from empty list

# %% [markdown]
# * 과제 1 : 이해가 안되시는 부분은 손으로 직접 써보세요.
# * 과제 2 : 값의 인덱스를 반환하는 find만 구현을 직접 해보세요. find말고 다른 기능들까지 구현하셔도 좋습니다. shift, unshift, get 등이요!

# %% [markdown]
# ### 1.4.3 트리와 그래프

# %% [markdown]
# #### 1.4.3.1 트리 구현
# * 트리의 기본형태
#     * value
#     * child - left
#     * child - right

# %%
{
    'value': 5,
    'left': {},
    'right': {}
}

# %% [markdown]
# 연습문제
# ![tree만들기.png](data:image/png;base64,...)

# %% [markdown]
# #### 1.4.3.1 트리의 순회
# object나 array(기존 자료형)로 tree나 linked list를 구현할 수 있는데 왜 class로 구현할까요?
# 1. 더 lite한 모델을 만들기 위해
# 2. 확장성
# 3. OOP(Object-Oriented Programming, 객체 지향 프로그래밍)에 철학에 맞기 때문에

# %% [markdown]
# ![tree만들기_트리순회.png](data:image/png;base64,...)

# %% [markdown]
# ![tree만들기_트리순회_2.png](data:image/png;base64,...)

# %% [markdown]
# ### 1.4.4 정렬 알고리즘
# * 재미있는 사실(재미없을 수도 있습니다. 사례를 말씀드릴게요.)
#     * JavaScript의 Array의 sort는 알고리즘이 고정이 아닙니다. 각 브라우저마다(벤더사마다) 다른 sort를 사용하고 있어서 같은 값이면 브라우저마다 보여지는 화면이 다를 수 있습니다.
#     * Google이 Chrome 70 이전에 개수에 따라 다른 알고리즘을 혼합하는 정렬을 사용했다가(InsertionSort & QuickSort 사용) 얼마전에(18년도에) Timsort로 변경했습니다.
#     * 정렬 알고리즘 중에서 가장 인기있는 알고리즘은 병합정렬(존 폰 노이만 제작)이었습니다.
#     * Python에서 시작된 Timsort로(팀 피터스) 대동단결하고 있는 모양세입니다. Python 만세!
#     * Timsort는 삽입정렬과 병합정렬을 적절히 조합한 것이고, 2002년도에 Python을 위해 C로 구현되었습니다.
#     * 정렬 알고리즘 3대장 비교(Bset, Worst)
#         * 병합 정렬 : nlogn, nlogn
#         * 퀵 정렬 : nlogn, n**2
#         * 팀소트 : n, nlogn

# %% [markdown]
# #### 1.4.4.1 선택정렬

# %% [markdown]
# * step 1
# ```
# 전 = [199, 22, 33, 12, 32, 64, 72, 222, 233]
# 후 = []
# ```
# * step 2
# ```
# 전 = [199, 22, 33, 32, 64, 72, 222, 233]
# 후 = [12]
# ```
# * step 3
# ```
# 전 = [199, 33, 32, 64, 72, 222, 233]
# 후 = [12, 22]
# ```
# * step 4
# ```
# 전 = [199, 33, 64, 72, 222, 233]
# 후 = [12, 22, 32]
# ```

# %% [markdown]
# #### 1.4.4.2 삽입정렬

# %% [markdown]
# ```
# 전 = [199, 22, 33, 12, 32, 64, 72, 222, 233]
# 후 = []
#
# 전 = [22, 33, 12, 32, 64, 72, 222, 233]
# 후 = [199]
#
# 전 = [33, 12, 32, 64, 72, 222, 233]
# 후 = [22, 199]
#
# 전 = [12, 32, 64, 72, 222, 233]
# 후 = [22, 33, 199]
#
# 전 = [32, 64, 72, 222, 233]
# 후 = [12, 22, 33, 199]
#
# 전 = [64, 72, 222, 233]
# 후 = [12, 22, 32, 33, 199]
#
# 전 = [72, 222, 233]
# 후 = [12, 22, 32, 33, 64, 199]
# ```

# %% [markdown]
# #### 1.4.4.3 병합정렬

# %% [markdown]
# * Worst와 Best 모두 O(nlogn), 어떤 정렬보다 빠름, 동일 할 수 있음
# * 분할 정복(Divide and Conquer)

# %% [markdown]
# ```python
#
# 입력값 = [5, 10, 66, 77, 54, 32, 11, 15]
# 정렬된배열 = []
#
# # 분할(이해를 돕기 위해 8개로 조정)
# [5, 10, 66, 77, 54, 32, 11, 15]
# [5, 10, 66, 77], [54, 32, 11, 15]
# [5, 10], [66, 77], [54, 32], [11, 15]
# [5], [10], [66], [77], [54], [32], [11], [15]
#
# # 정복(0번째끼리 비교!)
# [5, 10], [66, 77], [32, 54], [11, 15]
# [5, 10], [66, 77], [32, 54], [11, 15]
# [5, 10, 66, 77], [11, 15, 32, 54]
# [5, 10, 11, 15, 32, 54, 66, 77]
# ```

# %% [markdown]
# #### 1.4.4.4 퀵정렬

# %% [markdown]
# * best - O(nlog2n), worst - O(n**2)
# * 피봇값(pivot)을 기준으로 정렬(피봇값은 처음값, 중간값, 마지막 값)
# * 실무에서는 worst일 경우를 피하기 위해 피봇을 랜덤하게 주는 경우나, 피봇을 2개 사용하는 경우도 있음.
#
# ```python
# 입력값 = [66, 77, 54, 32, 10, 5, 11, 15]
#
# # step 1
# # 피봇값 : 66
# [54, 32, 10, 5, 11, 15] + [66] + [77]
#
# # step 2
# # 피봇값 : 54 (66과 77은 값이 한 개이기 때문에 더이상 재귀로 호출되지 않음.)
# [32, 10, 5, 11, 15] + [54] + [66] + [77]
#
# # step 3
# # 피봇값 : 32
# [10, 5, 11, 15] + [32] + [54] + [66] + [77]
#
# # step 4
# # 피봇값 : 10
# [5] + [10] + [11, 15] + [32] + [54] + [66] + [77]
#
# # step 5
# # 피봇값 : 11
# [5] + [10] + [11] + [15] + [32] + [54] + [66] + [77]
# ```

# %% [markdown]
# ### 1.4.5 페이지 교체 알고리즘

# %% [markdown]
# * https://www.notion.so/paullabworkspace/db83d9c4bbe6410ea208e6dc2daff07e
# * 페이지 교체 알고리즘 : 메모리를 효율적으로 사용하기 위해서 어떤 데이터를 메모리에 적재할지 결정하는 알고리즘
# * FIFO 알고리즘 (오래된 녀석이 가장 빨리 나간다)
#     * 순서 : 0, 4, 6, 5, 4, 7, 8
#     ```python
#     []
#     [0]
#     [0, 4]
#     [0, 4, 6]
#     [4, 6, 5]
#     [4, 6, 5] # 4가 hit
#     [6, 5, 7]
#     [5, 7, 8]
#     ```
# * LRU(오랫동안 사용되지 않은 녀석이 삭제)
#     * 순서 : 0, 4, 6, 5, 4, 7, 8
#     ```python
#     []
#     [0]
#     [0, 4]
#     [0, 4, 6]
#     [4, 6, 5]
#     [6, 5, 4] # 4가 hit
#     [5, 4, 7]
#     [4, 7, 8]
#     ```
#
# * 대표 문제 : https://tech.kakao.com/2017/09/27/kakao-blind-recruitment-round-1/
#
# * LRU 알고리즘 : 실행시간을 구하라!
#     * hit - 1초
#     * miss - 5초
#     * 캐시 - 3
#     ```python
#     ["바나나", "체리", "한라봉", "자몽", "수박", "수박", "체리"]
#     [바나나] # 5
#     [바나나, 체리] # 5
#     [바나나, 체리, 한라봉] # 5
#     [체리, 한라봉, 자몽] # 5
#     [한라봉, 자몽, 수박] # 5
#     [한라봉, 자몽, 수박] # 1 - hit
#     [자몽, 수박, 체리] # 5
#     ```
#
#
# * FIFO 알고리즘 : 실행시간을 구하라!
#     * hit - 1초
#     * miss - 5초
#     * 캐시 - 3
#     ```python
#     ["바나나", "체리", "한라봉", "자몽", "수박", "수박", "체리"]
#     [바나나] # 5
#     [바나나, 체리] # 5
#     [바나나, 체리, 한라봉] # 5
#     [체리, 한라봉, 자몽] # 5
#     [한라봉, 자몽, 수박] # 5
#     [한라봉, 자몽, 수박] # 1 - hit
#     [자몽, 수박, 체리] # 5
#     ```

# %% [markdown]
# ### 1.4.6 슬라이딩 윈도우와 투 포인터 알고리즘
# * 투 포인터 알고리즘 : 두개의 점의 위치(index)를 이용하여 순차적 해결
# * 슬라이딩 윈도우 알고리즘 : 고정 사이즈의 윈도우가 이동하면서 윈도우 내 데이터를 연산하여 문제 해결

# %% [markdown]
# ![tree만들기 (2).png](data:image/png;base64,...)

# %% [markdown]
# * 구간합이나 회문(팬린드롬) 등에 사용
#     * 예시 :
#     ```
#     슬라이딩 윈도우 : [1, 5, 4, 6, 4, 6, 7, 6, 4, 3, 1, 2]에서 연속된 2개의 합이 10인 모든 수를 찾아라.
#     투 포인터 : [1, 5, 4, 6, 4, 6, 7, 6, 4, 3, 1, 2]에서 연속된 배열의 합이 10인 배열의 인덱스를 모두 찾아라.
#     ```
#     * 예시가 아닌 것 :
#     ```
#     [1, 5, 4, 6, 4, 6, 7, 6, 4, 3, 1, 2]에서 2개의 수 조합으로 10을 만들 수 있는 배열의 인덱스를 찾아라.
#     ```
# * 회문 문제 : https://codingdojang.com/search/?q=palindrome

# %% [markdown]
# ## 1.5 재귀함수

# %% [markdown]
# ### 1.5.1 회문

# %% [markdown]
# * python에 3.5에서 추가된 type hint는 코드리뷰를 엄격하게 하는 회사에서 많이 사용합니다.(실무에서 많이 사용하는 추세입니다.)

# %% [markdown]
# ### 1.5.2 재귀를 통한 반복

# %%
# step1 : 반복문
# step2 : 재귀함수
# step3 : 어려운 방법으로 풀이(피보나치)

# %% [markdown]
# ### 1.5.3 재귀를 이용한 반복 (피보나치)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 1.5.4 데코레이터, 클로저(팩토리 함수)

# %% [markdown]
# 강의자료 링크 : https://paullabworkspace.notion.site/Python-a8b9c611beef4740a6372c27a270b70e?pvs=4
#
# ```
# @로그인
# def 비밀게시판():
#     #글쓰기
#     return None
#
# @전처리
# def 시각화():
#     #시각화 기능
#     return None
# ```

# %% [markdown]
# # 실전 대기업 문제 풀이

# %% [markdown]
# * 너무 어려운 문제는 제외하였습니다.
# * 문제 풀이는 워밍업, 18년, 19년, 20년, 21년 입사문제 풀이 순으로 진행합니다.
# * 문제는 한 해 전에 공개됩니다. 예를 들어 2020 공채라면 19년에 시험을 보기 때문입니다.

# %% [markdown]
# ## 카카오 2018 공채 문제 1번
# * 비밀지도 문제 링크 : https://school.programmers.co.kr/learn/courses/30/lessons/17681

# %% [markdown]
# ## 카카오 2018 공채 문제 2번
# * 다트게임 문제 링크 : https://school.programmers.co.kr/learn/courses/30/lessons/17682

# %% [markdown]
# ## 카카오 2018 공채 문제 3번
# * 캐시 문제 링크 :
# https://school.programmers.co.kr/learn/courses/30/lessons/17680

# %%
도시이름 = ['Jeju', 'Pangyo', 'Seoul', 'NewYork', 'LA', 'Jeju', 'Pangyo', 'Seoul', 'NewYork', 'LA']

# %% [markdown]
# ## 카카오 2018 공채 문제 4번
# 셔틀버스 문제 링크 : https://school.programmers.co.kr/learn/courses/30/lessons/17678

# %% [markdown]
# ## 카카오 2018 공채 문제 5번
# * 뉴스 클러스터링 문제 링크 : https://school.programmers.co.kr/learn/courses/30/lessons/17677

# %% [markdown]
# ## 카카오 2018 공채 문제 6번
# * 프렌즈4블록 문제 링크 : https://school.programmers.co.kr/learn/courses/30/lessons/17679

# %% [markdown]
# ## 카카오 2019 공채 문제 1번
# * 카카오 오픈 채팅방 : https://school.programmers.co.kr/learn/courses/30/lessons/42888

# %% [markdown]
# ## 카카오 2019 공채 문제 2번
# * 실패율 링크 : https://school.programmers.co.kr/learn/courses/30/lessons/42889

# %% [markdown]
# ## 카카오 2019 공채 문제 3번
# * 후보키 : https://school.programmers.co.kr/learn/courses/30/lessons/42890

# %% [markdown]
# ## 카카오 2019 공채 문제 4번
# * 무지의 먹방 라이브 문제 링크 : https://school.programmers.co.kr/learn/courses/30/lessons/42891

# %% [markdown]
# ## 카카오 2020 공채 문제 1번
# * 문자열 압축 문제 링크 : https://school.programmers.co.kr/learn/courses/30/lessons/60057

# %% [markdown]
# ## 14번 카카오 2020 공채 문제 4번
# * 가사 검색 문제 링크 : https://school.programmers.co.kr/learn/courses/30/lessons/60060

# %% [markdown]
# ## 카카오 2021 공채 문제 1번
# * 신규 아이디 추천 문제 링크 : https://school.programmers.co.kr/learn/courses/30/lessons/72410

# %% [markdown]
# ## 카카오 2021 공채 문제 2번
# * 메뉴 리뉴얼 문제 링크 : https://school.programmers.co.kr/learn/courses/30/lessons/72411
